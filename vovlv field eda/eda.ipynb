# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vpd.csv")

# %%
df
# Out:
#          DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0      07-Apr-14                7405         15/9-F-1 C            0.0
# 1      08-Apr-14                7405         15/9-F-1 C            0.0
# 2      09-Apr-14                7405         15/9-F-1 C            0.0
# 3      10-Apr-14                7405         15/9-F-1 C            0.0
# 4      11-Apr-14                7405         15/9-F-1 C            0.0
# ...          ...                 ...                ...            ...
# 15629  14-Sep-16                5769           15/9-F-5            0.0
# 15630  15-Sep-16                5769           15/9-F-5            0.0
# 15631  16-Sep-16                5769           15/9-F-5            0.0
# 15632  17-Sep-16                5769           15/9-F-5            0.0
# 15633  18-Sep-16                5769           15/9-F-5            0.0
#
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   15634 non-null  object
#  1   NPD_WELL_BORE_CODE        15634 non-null  int64
#  2   NPD_WELL_BORE_NAME        15634 non-null  object
#  3   ON_STREAM_HRS             15349 non-null  float64
#  4   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  5   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  6   AVG_DP_TUBING             8980 non-null   float64
#  7   AVG_ANNULUS_PRESS         7890 non-null   float64
#  8   AVG_CHOKE_SIZE_P          8919 non-null   float64
#  9   AVG_CHOKE_UOM             9161 non-null   object
#  10  AVG_WHP_P                 9155 non-null   float64
#  11  AVG_WHT_P                 9146 non-null   float64
#  12  DP_CHOKE_SIZE             15340 non-null  float64
# ...

# %%
df.head()
# Out:
#      DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0  07-Apr-14                7405         15/9-F-1 C            0.0
# 1  08-Apr-14                7405         15/9-F-1 C            0.0
# 2  09-Apr-14                7405         15/9-F-1 C            0.0
# 3  10-Apr-14                7405         15/9-F-1 C            0.0
# 4  11-Apr-14                7405         15/9-F-1 C            0.0
#
#    AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                  0.000                     0.000          0.000
# 1                    NaN                       NaN            NaN
# 2                    NaN                       NaN            NaN
# 3                    NaN                       NaN            NaN
# 4                310.376                    96.876        277.278
#
#    AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  \
# 0                0.0           0.00000             %      0.000       0.00
# ...

# %%
df.describe()
# Out:
#        NPD_WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# count        15634.000000   15349.000000            8980.000000
# mean          5908.581745      19.994172             181.803870
# std            649.231622       8.369911             109.712365
# min           5351.000000       0.000000               0.000000
# 25%           5599.000000      24.000000               0.000000
# 50%           5693.000000      24.000000             232.897000
# 75%           5769.000000      24.000000             255.401250
# max           7405.000000      25.000000             397.589000
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# count               8980.000000    8980.000000        7890.000000
# mean                  77.162970     154.028791          14.856100
# std                   45.657949      76.752381           8.406821
# min                    0.000000       0.000000           0.000000
# ...

# %%
df.transpose()
# Out:
#                                0           1           2           3      \
# DATEPRD                    07-Apr-14   08-Apr-14   09-Apr-14   10-Apr-14
# NPD_WELL_BORE_CODE              7405        7405        7405        7405
# NPD_WELL_BORE_NAME        15/9-F-1 C  15/9-F-1 C  15/9-F-1 C  15/9-F-1 C
# ON_STREAM_HRS                    0.0         0.0         0.0         0.0
# AVG_DOWNHOLE_PRESSURE            0.0         NaN         NaN         NaN
# AVG_DOWNHOLE_TEMPERATURE         0.0         NaN         NaN         NaN
# AVG_DP_TUBING                    0.0         NaN         NaN         NaN
# AVG_ANNULUS_PRESS                0.0         0.0         0.0         0.0
# AVG_CHOKE_SIZE_P                 0.0     1.00306     0.97901     0.54576
# AVG_CHOKE_UOM                      %           %           %           %
# AVG_WHP_P                        0.0         0.0         0.0         0.0
# AVG_WHT_P                        0.0         0.0         0.0         0.0
# ...

# %%
df["NPD_WELL_BORE_NAME"].unique()
# Out:
# array(['15/9-F-1 C', '15/9-F-11', '15/9-F-12', '15/9-F-14', '15/9-F-15 D',
#        '15/9-F-4', '15/9-F-5'], dtype=object)

# %%
df["NPD_WELL_BORE_NAME"].value_counts()
# Out:
# NPD_WELL_BORE_NAME
# 15/9-F-4       3327
# 15/9-F-5       3306
# 15/9-F-12      3056
# 15/9-F-14      3056
# 15/9-F-11      1165
# 15/9-F-15 D     978
# 15/9-F-1 C      746
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="NPD_WELL_BORE_NAME")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, '15/9-F-1 C'),
#   Text(1, 0, '15/9-F-11'),
#   Text(2, 0, '15/9-F-12'),
#   Text(3, 0, '15/9-F-14'),
#   Text(4, 0, '15/9-F-15 D'),
#   Text(5, 0, '15/9-F-4'),
#   Text(6, 0, '15/9-F-5')])

# %%
df.head()
# Out:
#      DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0  07-Apr-14                7405         15/9-F-1 C            0.0
# 1  08-Apr-14                7405         15/9-F-1 C            0.0
# 2  09-Apr-14                7405         15/9-F-1 C            0.0
# 3  10-Apr-14                7405         15/9-F-1 C            0.0
# 4  11-Apr-14                7405         15/9-F-1 C            0.0
#
#    AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                  0.000                     0.000          0.000
# 1                    NaN                       NaN            NaN
# 2                    NaN                       NaN            NaN
# 3                    NaN                       NaN            NaN
# 4                310.376                    96.876        277.278
#
#    AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  \
# 0                0.0           0.00000             %      0.000       0.00
# ...

# %%
sns.countplot(data=df,x="FLOW_KIND")
# Out:
# <Axes: xlabel='FLOW_KIND', ylabel='count'>

# %%
df.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                285
# AVG_DOWNHOLE_PRESSURE       6654
# AVG_DOWNHOLE_TEMPERATURE    6654
# AVG_DP_TUBING               6654
# AVG_ANNULUS_PRESS           7744
# AVG_CHOKE_SIZE_P            6715
# AVG_CHOKE_UOM               6473
# AVG_WHP_P                   6479
# AVG_WHT_P                   6488
# DP_CHOKE_SIZE                294
# BORE_OIL_VOL                6473
# BORE_GAS_VOL                6473
# BORE_WAT_VOL                6473
# BORE_WI_VOL                 9928
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.plot(subplots = True,figsize =(16,10))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)

# %%
df["NPD_WELL_BORE_NAME"].value_counts()
# Out:
# NPD_WELL_BORE_NAME
# 15/9-F-4       3327
# 15/9-F-5       3306
# 15/9-F-12      3056
# 15/9-F-14      3056
# 15/9-F-11      1165
# 15/9-F-15 D     978
# 15/9-F-1 C      746
# Name: count, dtype: int64

# %% [markdown]
# ## well1 f12

# %%
df["NPD_WELL_BORE_NAME"]=="15/9-F-12"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15629    False
# 15630    False
# 15631    False
# 15632    False
# 15633    False
# Name: NPD_WELL_BORE_NAME, Length: 15634, dtype: bool

# %%
df[df["NPD_WELL_BORE_NAME"]=="15/9-F-12"]
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 1911  12-Feb-08                5599          15/9-F-12          11.50
# 1912  13-Feb-08                5599          15/9-F-12          24.00
# 1913  14-Feb-08                5599          15/9-F-12          22.50
# 1914  15-Feb-08                5599          15/9-F-12          23.15
# 1915  16-Feb-08                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 4962  13-Sep-16                5599          15/9-F-12           0.00
# 4963  14-Sep-16                5599          15/9-F-12           0.00
# 4964  15-Sep-16                5599          15/9-F-12           0.00
# 4965  16-Sep-16                5599          15/9-F-12           0.00
# 4966  17-Sep-16                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1=df[df["NPD_WELL_BORE_NAME"]=="15/9-F-12"]

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 1911  12-Feb-08                5599          15/9-F-12          11.50
# 1912  13-Feb-08                5599          15/9-F-12          24.00
# 1913  14-Feb-08                5599          15/9-F-12          22.50
# 1914  15-Feb-08                5599          15/9-F-12          23.15
# 1915  16-Feb-08                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 4962  13-Sep-16                5599          15/9-F-12           0.00
# 4963  14-Sep-16                5599          15/9-F-12           0.00
# 4964  15-Sep-16                5599          15/9-F-12           0.00
# 4965  16-Sep-16                5599          15/9-F-12           0.00
# 4966  17-Sep-16                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1.reset_index()
# Out:
#       index    DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0      1911  12-Feb-08                5599          15/9-F-12          11.50
# 1      1912  13-Feb-08                5599          15/9-F-12          24.00
# 2      1913  14-Feb-08                5599          15/9-F-12          22.50
# 3      1914  15-Feb-08                5599          15/9-F-12          23.15
# 4      1915  16-Feb-08                5599          15/9-F-12          24.00
# ...     ...        ...                 ...                ...            ...
# 3051   4962  13-Sep-16                5599          15/9-F-12           0.00
# 3052   4963  14-Sep-16                5599          15/9-F-12           0.00
# 3053   4964  15-Sep-16                5599          15/9-F-12           0.00
# 3054   4965  16-Sep-16                5599          15/9-F-12           0.00
# 3055   4966  17-Sep-16                5599          15/9-F-12           0.00
#
# ...

# %%
df_well1=df_well1.reset_index()

# %%
df_well1
# Out:
#       index    DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0      1911  12-Feb-08                5599          15/9-F-12          11.50
# 1      1912  13-Feb-08                5599          15/9-F-12          24.00
# 2      1913  14-Feb-08                5599          15/9-F-12          22.50
# 3      1914  15-Feb-08                5599          15/9-F-12          23.15
# 4      1915  16-Feb-08                5599          15/9-F-12          24.00
# ...     ...        ...                 ...                ...            ...
# 3051   4962  13-Sep-16                5599          15/9-F-12           0.00
# 3052   4963  14-Sep-16                5599          15/9-F-12           0.00
# 3053   4964  15-Sep-16                5599          15/9-F-12           0.00
# 3054   4965  16-Sep-16                5599          15/9-F-12           0.00
# 3055   4966  17-Sep-16                5599          15/9-F-12           0.00
#
# ...

# %%
df_well1=df_well1.drop("index",axis = 1)

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0     12-Feb-08                5599          15/9-F-12          11.50
# 1     13-Feb-08                5599          15/9-F-12          24.00
# 2     14-Feb-08                5599          15/9-F-12          22.50
# 3     15-Feb-08                5599          15/9-F-12          23.15
# 4     16-Feb-08                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 3051  13-Sep-16                5599          15/9-F-12           0.00
# 3052  14-Sep-16                5599          15/9-F-12           0.00
# 3053  15-Sep-16                5599          15/9-F-12           0.00
# 3054  16-Sep-16                5599          15/9-F-12           0.00
# 3055  17-Sep-16                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3056 entries, 0 to 3055
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   object
#  1   NPD_WELL_BORE_CODE        3056 non-null   int64
#  2   NPD_WELL_BORE_NAME        3056 non-null   object
#  3   ON_STREAM_HRS             3056 non-null   float64
#  4   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  5   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  6   AVG_DP_TUBING             3050 non-null   float64
#  7   AVG_ANNULUS_PRESS         3043 non-null   float64
#  8   AVG_CHOKE_SIZE_P          3012 non-null   float64
#  9   AVG_CHOKE_UOM             3056 non-null   object
#  10  AVG_WHP_P                 3056 non-null   float64
#  11  AVG_WHT_P                 3056 non-null   float64
#  12  DP_CHOKE_SIZE             3056 non-null   float64
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(df_well1["DATEPRD"],df_well1["BORE_OIL_VOL"])

# %%
df_well1["DATEPRD"]=pd.to_datetime(df_well1["DATEPRD"])
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\1523333510.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well1["DATEPRD"]=pd.to_datetime(df_well1["DATEPRD"])

# %%
df_well1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3056 entries, 0 to 3055
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   datetime64[ns]
#  1   NPD_WELL_BORE_CODE        3056 non-null   int64
#  2   NPD_WELL_BORE_NAME        3056 non-null   object
#  3   ON_STREAM_HRS             3056 non-null   float64
#  4   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  5   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  6   AVG_DP_TUBING             3050 non-null   float64
#  7   AVG_ANNULUS_PRESS         3043 non-null   float64
#  8   AVG_CHOKE_SIZE_P          3012 non-null   float64
#  9   AVG_CHOKE_UOM             3056 non-null   object
#  10  AVG_WHP_P                 3056 non-null   float64
#  11  AVG_WHT_P                 3056 non-null   float64
#  12  DP_CHOKE_SIZE             3056 non-null   float64
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(df_well1["DATEPRD"],df_well1["BORE_OIL_VOL"])

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2008-02-12                5599          15/9-F-12          11.50
# 1    2008-02-13                5599          15/9-F-12          24.00
# 2    2008-02-14                5599          15/9-F-12          22.50
# 3    2008-02-15                5599          15/9-F-12          23.15
# 4    2008-02-16                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 3051 2016-09-13                5599          15/9-F-12           0.00
# 3052 2016-09-14                5599          15/9-F-12           0.00
# 3053 2016-09-15                5599          15/9-F-12           0.00
# 3054 2016-09-16                5599          15/9-F-12           0.00
# 3055 2016-09-17                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1[df_well1["DATEPRD"].dt.year==2011]
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 1042 2011-01-01                5599          15/9-F-12          24.00
# 1043 2011-01-02                5599          15/9-F-12          24.00
# 1044 2011-01-03                5599          15/9-F-12          23.50
# 1045 2011-01-04                5599          15/9-F-12          24.00
# 1046 2011-01-05                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 1373 2011-12-27                5599          15/9-F-12          17.00
# 1374 2011-12-28                5599          15/9-F-12          10.48
# 1375 2011-12-29                5599          15/9-F-12           0.00
# 1376 2011-12-30                5599          15/9-F-12          24.00
# 1377 2011-12-31                5599          15/9-F-12          24.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
# function for dealing with individual well data

def dataformat(df,wellbore_name):
    """function for getting data of a particular well from the master dataframe

inputs ->

df: master dataframe
wellbore_name: wellbore  whose data need to be extracted

return
df_well

"""
    df_well = df[df["NPD_WELL_BORE_NAME"]==wellbore_name]

    df_well = df_well.reset_index()
    
    df_well = df_well.drop("index",axis = 1)

    df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

    return df_well

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2008-02-12                5599          15/9-F-12          11.50
# 1    2008-02-13                5599          15/9-F-12          24.00
# 2    2008-02-14                5599          15/9-F-12          22.50
# 3    2008-02-15                5599          15/9-F-12          23.15
# 4    2008-02-16                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 3051 2016-09-13                5599          15/9-F-12           0.00
# 3052 2016-09-14                5599          15/9-F-12           0.00
# 3053 2016-09-15                5599          15/9-F-12           0.00
# 3054 2016-09-16                5599          15/9-F-12           0.00
# 3055 2016-09-17                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1.plot(subplots = True,figsize= (16,8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
sns.heatmap(df_well1.isna())
# Out:
# <Axes: >

# %%
df_well1.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS             13
# AVG_CHOKE_SIZE_P              44
# AVG_CHOKE_UOM                  0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
plt.figure(figsize=(16,6))
df_well1["AVG_CHOKE_SIZE_P"].plot()
# Out:
# <Axes: >

# %%
df_well1["AVG_CHOKE_SIZE_P"].loc[300:500].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2008-02-12                5599          15/9-F-12          11.50
# 1    2008-02-13                5599          15/9-F-12          24.00
# 2    2008-02-14                5599          15/9-F-12          22.50
# 3    2008-02-15                5599          15/9-F-12          23.15
# 4    2008-02-16                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 3051 2016-09-13                5599          15/9-F-12           0.00
# 3052 2016-09-14                5599          15/9-F-12           0.00
# 3053 2016-09-15                5599          15/9-F-12           0.00
# 3054 2016-09-16                5599          15/9-F-12           0.00
# 3055 2016-09-17                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
sns.heatmap(df_well1.isna())
# Out:
# <Axes: >

# %%
df_well1["AVG_CHOKE_SIZE_P"] = df_well1["AVG_CHOKE_SIZE_P"].interpolate(method="linear")

# %%
sns.heatmap(df_well1.isna())
# Out:
# <Axes: >

# %%
df_well1.isna()
# Out:
#       DATEPRD  NPD_WELL_BORE_CODE  NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0       False               False               False          False
# 1       False               False               False          False
# 2       False               False               False          False
# 3       False               False               False          False
# 4       False               False               False          False
# ...       ...                 ...                 ...            ...
# 3051    False               False               False          False
# 3052    False               False               False          False
# 3053    False               False               False          False
# 3054    False               False               False          False
# 3055    False               False               False          False
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well1.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS             13
# AVG_CHOKE_SIZE_P               0
# AVG_CHOKE_UOM                  0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
df_well1[["AVG_ANNULUS_PRESS","AVG_WHT_P"]].loc[500:700].plot(figsize= (16,4))
# Out:
# <Axes: >

# %%
df_well1=df_well1.drop("NPD_WELL_BORE_NAME",axis = 1)

# %%
df_well1
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0    2008-02-12                5599          11.50                308.056
# 1    2008-02-13                5599          24.00                303.034
# 2    2008-02-14                5599          22.50                295.586
# 3    2008-02-15                5599          23.15                297.663
# 4    2008-02-16                5599          24.00                295.936
# ...         ...                 ...            ...                    ...
# 3051 2016-09-13                5599           0.00                  0.000
# 3052 2016-09-14                5599           0.00                  0.000
# 3053 2016-09-15                5599           0.00                  0.000
# 3054 2016-09-16                5599           0.00                  0.000
# 3055 2016-09-17                5599           0.00                  0.000
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# ...

# %%
df_well1=df_well1.drop("FLOW_KIND",axis=1)
df_well1=df_well1.drop("WELL_TYPE",axis=1)
df_well1=df_well1.drop("AVG_CHOKE_UOM",axis=1)

# %%
df_well1.corr()
# Out:
#                            DATEPRD  NPD_WELL_BORE_CODE  ON_STREAM_HRS  \
# DATEPRD                   1.000000                 NaN      -0.082624
# NPD_WELL_BORE_CODE             NaN                 NaN            NaN
# ON_STREAM_HRS            -0.082624                 NaN       1.000000
# AVG_DOWNHOLE_PRESSURE    -0.799625                 NaN       0.080646
# AVG_DOWNHOLE_TEMPERATURE -0.803474                 NaN       0.096129
# AVG_DP_TUBING            -0.781943                 NaN       0.016535
# AVG_ANNULUS_PRESS         0.153522                 NaN       0.567245
# AVG_CHOKE_SIZE_P          0.315302                 NaN       0.601551
# AVG_WHP_P                -0.632512                 NaN      -0.076573
# AVG_WHT_P                -0.086225                 NaN       0.840726
# DP_CHOKE_SIZE            -0.568199                 NaN      -0.284239
# BORE_OIL_VOL             -0.787193                 NaN       0.296982
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_ap= df_well1[["AVG_ANNULUS_PRESS","AVG_WHT_P"]]

# %%
df_ap
# Out:
#       AVG_ANNULUS_PRESS  AVG_WHT_P
# 0                18.640     16.295
# 1                16.467     53.374
# 2                12.660     72.738
# 3                 5.264     69.996
# 4                12.385     71.518
# ...                 ...        ...
# 3051             19.959      0.000
# 3052             19.959      0.000
# 3053             19.959      0.000
# 3054             19.959      0.000
# 3055             19.959      0.000
#
# [3056 rows x 2 columns]

# %%
scaler = MinMaxScaler()

# %%
scaled_data = scaler.fit_transform(df_ap)

# %%
scaled_df= pd.DataFrame(scaled_data,columns = df_ap.columns)

# %%
scaled_df.loc[500:700].plot(figsize=(18,4))
# Out:
# <Axes: >

# %%
scaled_df[scaled_df["AVG_ANNULUS_PRESS"].isna()]
# Out:
#      AVG_ANNULUS_PRESS  AVG_WHT_P
# 636                NaN   0.878768
# 637                NaN   0.881829
# 638                NaN   0.882716
# 639                NaN   0.879914
# 640                NaN   0.892060
# 641                NaN   0.878043
# 642                NaN   0.848354
# 643                NaN   0.888945
# 644                NaN   0.882845
# 645                NaN   0.871273
# 646                NaN   0.868093
# 647                NaN   0.869185
# 648                NaN   0.863756

# %%
df_well1.loc[635][["AVG_ANNULUS_PRESS","AVG_WHT_P"]]
# Out:
# AVG_ANNULUS_PRESS    15.075
# AVG_WHT_P            80.762
# Name: 635, dtype: object

# %%
dif = df_well1.loc[635]["AVG_WHT_P"] - df_well1.loc[635]["AVG_ANNULUS_PRESS"]

# %%
dif
# Out:
# 65.687

# %%
df_well1[df_well1["AVG_ANNULUS_PRESS"].isna()][["AVG_ANNULUS_PRESS","AVG_WHT_P"]]
# Out:
#      AVG_ANNULUS_PRESS  AVG_WHT_P
# 636                NaN     81.250
# 637                NaN     81.533
# 638                NaN     81.615
# 639                NaN     81.356
# 640                NaN     82.479
# 641                NaN     81.183
# 642                NaN     78.438
# 643                NaN     82.191
# 644                NaN     81.627
# 645                NaN     80.557
# 646                NaN     80.263
# 647                NaN     80.364
# 648                NaN     79.862

# %%
df_well1["AVG_ANNULUS_PRESS"]= np.where(df_well1["AVG_ANNULUS_PRESS"].isna(),df_well1["AVG_WHT_P"]-dif,df_well1["AVG_ANNULUS_PRESS"])

# %%
df_well1[["AVG_ANNULUS_PRESS","AVG_WHT_P"]].loc[500:700].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
sns.heatmap(df_well1.isna())
# Out:
# <Axes: >

# %%
df_well1.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS              0
# AVG_CHOKE_SIZE_P               0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# dtype: int64

# %%
df_well1["AVG_DOWNHOLE_PRESSURE"] = df_well1["AVG_DOWNHOLE_PRESSURE"].interpolate(method="linear")
df_well1["AVG_DOWNHOLE_TEMPERATURE"] = df_well1["AVG_DOWNHOLE_TEMPERATURE"].interpolate(method="linear")
df_well1["AVG_DP_TUBING"] = df_well1["AVG_DP_TUBING"].interpolate(method="linear")
df_well1.drop("BORE_WI_VOL",axis=1)
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0    2008-02-12                5599          11.50                308.056
# 1    2008-02-13                5599          24.00                303.034
# 2    2008-02-14                5599          22.50                295.586
# 3    2008-02-15                5599          23.15                297.663
# 4    2008-02-16                5599          24.00                295.936
# ...         ...                 ...            ...                    ...
# 3051 2016-09-13                5599           0.00                  0.000
# 3052 2016-09-14                5599           0.00                  0.000
# 3053 2016-09-15                5599           0.00                  0.000
# 3054 2016-09-16                5599           0.00                  0.000
# 3055 2016-09-17                5599           0.00                  0.000
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# ...

# %%
df_well1.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          0
# AVG_DOWNHOLE_TEMPERATURE       0
# AVG_DP_TUBING                  0
# AVG_ANNULUS_PRESS              0
# AVG_CHOKE_SIZE_P               0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# dtype: int64

# %%
# droping columns from well f_12
df_well1= df_well1.drop(["AVG_DOWNHOLE_PRESSURE","AVG_DOWNHOLE_TEMPERATURE","BORE_WI_VOL"],axis=1)

# %%
sns.heatmap(df_well1.isna())
# Out:
# <Axes: >

# %%
df_well1.set_index("DATEPRD").plot(subplots = True, figsize=(12,10))
# Out:
# array([<Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>], dtype=object)

# %%
df["NPD_WELL_BORE_NAME"].value_counts()
# Out:
# NPD_WELL_BORE_NAME
# 15/9-F-4       3327
# 15/9-F-5       3306
# 15/9-F-12      3056
# 15/9-F-14      3056
# 15/9-F-11      1165
# 15/9-F-15 D     978
# 15/9-F-1 C      746
# Name: count, dtype: int64

# %% [markdown]
# ## well 2  15/9-F-14

# %%
df_well2 = dataformat(df,"15/9-F-14")
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\4265093265.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

# %%
df_well2
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2008-02-12                5351          15/9-F-14            0.0
# 1    2008-02-13                5351          15/9-F-14            0.0
# 2    2008-02-14                5351          15/9-F-14            0.0
# 3    2008-02-15                5351          15/9-F-14            0.0
# 4    2008-02-16                5351          15/9-F-14            0.0
# ...         ...                 ...                ...            ...
# 3051 2016-09-13                5351          15/9-F-14            0.0
# 3052 2016-09-14                5351          15/9-F-14            0.0
# 3053 2016-09-15                5351          15/9-F-14            0.0
# 3054 2016-09-16                5351          15/9-F-14            0.0
# 3055 2016-09-17                5351          15/9-F-14            0.0
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well2.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS            523
# AVG_CHOKE_SIZE_P             196
# AVG_CHOKE_UOM                  0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
df_well2.set_index("DATEPRD").plot(subplots=True,figsize=(14,10))
# Out:
# array([<Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>,
#        <Axes: xlabel='DATEPRD'>, <Axes: xlabel='DATEPRD'>], dtype=object)

# %%
df_well2["AVG_ANNULUS_PRESS"]
# Out:
# 0        0.000
# 1        0.000
# 2        0.000
# 3        0.000
# 4        0.000
#          ...
# 3051    10.583
# 3052    10.583
# 3053    10.582
# 3054    10.583
# 3055    10.583
# Name: AVG_ANNULUS_PRESS, Length: 3056, dtype: float64

# %%
sns.heatmap(df_well2.isna())
# Out:
# <Axes: >

# %%
df_well2= df_well2.drop(["NPD_WELL_BORE_NAME","FLOW_KIND","WELL_TYPE","AVG_CHOKE_UOM"],axis=1)

# %%
df_well2.corr()
# Out:
#                            DATEPRD  NPD_WELL_BORE_CODE  ON_STREAM_HRS  \
# DATEPRD                   1.000000                 NaN       0.193028
# NPD_WELL_BORE_CODE             NaN                 NaN            NaN
# ON_STREAM_HRS             0.193028                 NaN       1.000000
# AVG_DOWNHOLE_PRESSURE     0.337543                 NaN       0.539416
# AVG_DOWNHOLE_TEMPERATURE  0.139063                 NaN       0.666586
# AVG_DP_TUBING             0.555584                 NaN       0.499939
# AVG_ANNULUS_PRESS         0.708039                 NaN       0.314393
# AVG_CHOKE_SIZE_P          0.477596                 NaN       0.589359
# AVG_WHP_P                -0.457800                 NaN       0.227252
# AVG_WHT_P                 0.247783                 NaN       0.925476
# DP_CHOKE_SIZE            -0.614514                 NaN      -0.258025
# BORE_OIL_VOL             -0.677477                 NaN       0.379334
# ...

# %%
df_well2["AVG_ANNULUS_PRESS"].loc[1:2000].plot(figsize=(18,4))
# Out:
# <Axes: >

# %%
df_well2["AVG_ANNULUS_PRESS"]= df_well2["AVG_ANNULUS_PRESS"].interpolate(method="linear")

# %%
df_well2["AVG_ANNULUS_PRESS"].loc[1:2000].plot(figsize=(18,4))
# Out:
# <Axes: >

# %%
sns.heatmap(df_well2.isna())
# Out:
# <Axes: >

# %%
df_well2["AVG_CHOKE_SIZE_P"].loc[1:1300].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
df_well2[["AVG_CHOKE_SIZE_P","BORE_WAT_VOL"]].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
df_well2[["AVG_CHOKE_SIZE_P","BORE_WAT_VOL"]].loc[190:230]
# Out:
#      AVG_CHOKE_SIZE_P  BORE_WAT_VOL
# 190               NaN           0.0
# 191               NaN           0.0
# 192               NaN           0.0
# 193               NaN           0.0
# 194               NaN           0.0
# 195               NaN           0.0
# 196               NaN           0.0
# 197               NaN           0.0
# 198               NaN           0.0
# 199          24.32842           3.0
# 200               NaN           0.0
# 201          26.22610           1.0
# 202          26.84607           1.0
# 203          27.02818           1.0
# 204          27.18871           1.0
# 205          26.66966           1.0
# 206               NaN           0.0
# 207          26.06243           1.0
# 208          27.52529           1.0
# 209          39.69013           6.0
# 210          42.01485           8.0
# 211          42.04636           8.0
# 212          44.17549           6.0
# 213          44.79585           7.0
# 214          45.06599           7.0
# ...

# %%
df_bp= df_well2[["AVG_CHOKE_SIZE_P","BORE_WAT_VOL"]].loc[1:1300]

# %%
scaled_ef= scaler.fit_transform(df_bp)

# %%
scaled_ef= pd.DataFrame(scaled_data,columns= df_bp.columns)

# %%
scaled_ef.loc[0:150].plot(figsize=(18,4))
# Out:
# <Axes: >

# %%
#df_well2[["AVG_CHOKE_SIZE_P","BORE_WAT_VOL"]].loc[900:950]

# %%
df_bp.plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
df_well2["AVG_CHOKE_SIZE_P"] = df_well2["AVG_CHOKE_SIZE_P"].interpolate(method="linear")

# %%
df_well2["AVG_CHOKE_SIZE_P"].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
sns.heatmap(df_well2.isna())
# Out:
# <Axes: >

# %%
nan = np.random.rand(47)

# %%
nan
# Out:
# array([0.97142814, 0.27597178, 0.13861995, 0.28826076, 0.1458383 ,
#        0.80234325, 0.88997913, 0.54291782, 0.06015956, 0.74564624,
#        0.65707125, 0.79140814, 0.22735896, 0.63818013, 0.00287363,
#        0.36800995, 0.92395469, 0.07182487, 0.40790206, 0.08146398,
#        0.80980924, 0.02321766, 0.31499441, 0.46975224, 0.99404197,
#        0.47273547, 0.66012703, 0.69454368, 0.79400946, 0.42666699,
#        0.17121895, 0.42196107, 0.24718657, 0.35680045, 0.88707309,
#        0.12155598, 0.48423726, 0.29544324, 0.55726088, 0.67458617,
#        0.40358185, 0.71977615, 0.84320878, 0.80161101, 0.95697958,
#        0.06264479, 0.8130537 ])

# %%
#df_well2["AVG_CHOKE_SIZE_P"]=df_well2["AVG_CHOKE_SIZE_P"].loc[0:46]-nan[0:47]

# %%
df_well2["AVG_CHOKE_SIZE_P"]= np.where(df_well2["AVG_CHOKE_SIZE_P"].isna(),df_well2["BORE_WAT_VOL"]+0.01,df_well2["AVG_CHOKE_SIZE_P"])

# %%
df_well2.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS              0
# AVG_CHOKE_SIZE_P               0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# dtype: int64

# %%
df_well2["AVG_DOWNHOLE_PRESSURE"]= df_well2["AVG_DOWNHOLE_PRESSURE"].interpolate(method="linear")
df_well2["AVG_DOWNHOLE_TEMPERATURE"]= df_well2["AVG_DOWNHOLE_TEMPERATURE"].interpolate(method="linear")
df_well2["AVG_DP_TUBING"]= df_well2["AVG_DP_TUBING"].interpolate(method="linear")

# %%
df_well2= df_well2.drop(["BORE_WI_VOL"],axis=1)

# %%
sns.heatmap(df_well2.isna())
# Out:
# <Axes: >

# %%
df_well2.plot(subplots=True,figsize=(16,8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ## df_well3 15/9-F-11

# %%
df_well3 = dataformat(df,"15/9-F-11")
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\4265093265.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

# %%
df_well3
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2013-07-08                7078          15/9-F-11           0.00
# 1    2013-07-09                7078          15/9-F-11           0.00
# 2    2013-07-10                7078          15/9-F-11           0.00
# 3    2013-07-11                7078          15/9-F-11           0.00
# 4    2013-07-12                7078          15/9-F-11           0.00
# ...         ...                 ...                ...            ...
# 1160 2016-09-13                7078          15/9-F-11          24.00
# 1161 2016-09-14                7078          15/9-F-11          24.00
# 1162 2016-09-15                7078          15/9-F-11          24.00
# 1163 2016-09-16                7078          15/9-F-11          24.00
# 1164 2016-09-17                7078          15/9-F-11           8.28
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
df_well3.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS              6
# AVG_CHOKE_SIZE_P               2
# AVG_CHOKE_UOM                  0
# AVG_WHP_P                      6
# AVG_WHT_P                      6
# DP_CHOKE_SIZE                  6
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 1165
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
df_well3["AVG_DOWNHOLE_PRESSURE"] = df_well3["AVG_DOWNHOLE_PRESSURE"].interpolate(method="linear")
df_well3["AVG_DOWNHOLE_TEMPERATURE"] = df_well3["AVG_DOWNHOLE_TEMPERATURE"].interpolate(method="linear")
df_well3["AVG_DP_TUBING"] = df_well3["AVG_DP_TUBING"].interpolate(method="linear")
df_well3["AVG_ANNULUS_PRESS"] = df_well3["AVG_ANNULUS_PRESS"].interpolate(method="linear")
df_well3["AVG_CHOKE_SIZE_P"] = df_well3["AVG_CHOKE_SIZE_P"].interpolate(method="linear")
df_well3["AVG_WHP_P"] = df_well3["AVG_WHP_P"].interpolate(method="linear")
df_well3["AVG_WHT_P"] = df_well3["AVG_WHT_P"].interpolate(method="linear")
df_well3["DP_CHOKE_SIZE"] = df_well3["DP_CHOKE_SIZE"].interpolate(method="linear")
df_well3= df_well3.drop("BORE_WI_VOL",axis=1)

# %%
sns.heatmap(df_well3.isna())
# Out:
# <Axes: >

# %% [markdown]
# ## df_well4 15/9-F-1 c"

# %%
df_well4= dataformat(df,"15/9-F-1 C")
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\4265093265.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

# %%
df_well4
# Out:
#        DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0   2014-04-07                7405         15/9-F-1 C            0.0
# 1   2014-04-08                7405         15/9-F-1 C            0.0
# 2   2014-04-09                7405         15/9-F-1 C            0.0
# 3   2014-04-10                7405         15/9-F-1 C            0.0
# 4   2014-04-11                7405         15/9-F-1 C            0.0
# ..         ...                 ...                ...            ...
# 741 2016-04-17                7405         15/9-F-1 C            0.0
# 742 2016-04-18                7405         15/9-F-1 C            0.0
# 743 2016-04-19                7405         15/9-F-1 C            0.0
# 744 2016-04-20                7405         15/9-F-1 C            0.0
# 745 2016-04-21                7405         15/9-F-1 C            0.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                    0.000                     0.000          0.000
# ...

# %%
df_well4.isna().sum()
# Out:
# DATEPRD                       0
# NPD_WELL_BORE_CODE            0
# NPD_WELL_BORE_NAME            0
# ON_STREAM_HRS                 0
# AVG_DOWNHOLE_PRESSURE         3
# AVG_DOWNHOLE_TEMPERATURE      3
# AVG_DP_TUBING                 3
# AVG_ANNULUS_PRESS           729
# AVG_CHOKE_SIZE_P              0
# AVG_CHOKE_UOM                 0
# AVG_WHP_P                     0
# AVG_WHT_P                     0
# DP_CHOKE_SIZE                 0
# BORE_OIL_VOL                  0
# BORE_GAS_VOL                  0
# BORE_WAT_VOL                  0
# BORE_WI_VOL                 746
# FLOW_KIND                     0
# WELL_TYPE                     0
# dtype: int64

# %%
sns.heatmap(df_well4.isna())
# Out:
# <Axes: >

# %%
df_well4["AVG_DOWNHOLE_PRESSURE"]= df_well4["AVG_DOWNHOLE_PRESSURE"].interpolate(method="linear")
df_well4["AVG_DOWNHOLE_TEMPERATURE"]= df_well4["AVG_DOWNHOLE_TEMPERATURE"].interpolate(method="linear")
df_well4["AVG_DP_TUBING"]= df_well4["AVG_DP_TUBING"].interpolate(method="linear")
df_well4= df_well4.drop("AVG_ANNULUS_PRESS",axis=1)
df_well4= df_well4.drop("BORE_WI_VOL",axis=1)

# %%
sns.heatmap(df_well4.isna())
# Out:
# <Axes: >

# %% [markdown]
# ## well-5 15/9-F-15 D

# %%
df_well5= dataformat(df,"15/9-F-15 D")
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\4265093265.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

# %%
df_well5
# Out:
#        DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0   2014-01-12                7289        15/9-F-15 D            0.0
# 1   2014-01-13                7289        15/9-F-15 D            0.0
# 2   2014-01-14                7289        15/9-F-15 D            0.0
# 3   2014-01-15                7289        15/9-F-15 D            0.0
# 4   2014-01-16                7289        15/9-F-15 D           24.0
# ..         ...                 ...                ...            ...
# 973 2016-09-13                7289        15/9-F-15 D            0.0
# 974 2016-09-14                7289        15/9-F-15 D            0.0
# 975 2016-09-15                7289        15/9-F-15 D            0.0
# 976 2016-09-16                7289        15/9-F-15 D            0.0
# 977 2016-09-17                7289        15/9-F-15 D            0.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                  303.747                    98.701        283.535
# ...

# %%
sns.heatmap(df_well5.isna())
# Out:
# <Axes: >

# %%
df_well5.isna().sum()
# Out:
# DATEPRD                       0
# NPD_WELL_BORE_CODE            0
# NPD_WELL_BORE_NAME            0
# ON_STREAM_HRS                 0
# AVG_DOWNHOLE_PRESSURE         0
# AVG_DOWNHOLE_TEMPERATURE      0
# AVG_DP_TUBING                 0
# AVG_ANNULUS_PRESS             0
# AVG_CHOKE_SIZE_P              0
# AVG_CHOKE_UOM                 0
# AVG_WHP_P                     0
# AVG_WHT_P                     0
# DP_CHOKE_SIZE                 0
# BORE_OIL_VOL                  0
# BORE_GAS_VOL                  0
# BORE_WAT_VOL                  0
# BORE_WI_VOL                 978
# FLOW_KIND                     0
# WELL_TYPE                     0
# dtype: int64

# %%
df_well5= df_well5.drop("BORE_WI_VOL",axis=1)

# %%
sns.heatmap(df_well5.isna())
# Out:
# <Axes: >

# %%
df["NPD_WELL_BORE_NAME"].unique()
# Out:
# array(['15/9-F-1 C', '15/9-F-11', '15/9-F-12', '15/9-F-14', '15/9-F-15 D',
#        '15/9-F-4', '15/9-F-5'], dtype=object)

# %% [markdown]
# ## well6 15/9-F-4

# %%
df_well6=dataformat(df,"15/9-F-4")
# Out:
# C:\Users\tutua\AppData\Local\Temp\ipykernel_9092\4265093265.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_well["DATEPRD"] =pd.to_datetime(df_well["DATEPRD"])

# %%
df_well6
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0    2007-09-01                5693           15/9-F-4            NaN
# 1    2007-09-02                5693           15/9-F-4            NaN
# 2    2007-09-03                5693           15/9-F-4            NaN
# 3    2007-09-04                5693           15/9-F-4            NaN
# 4    2007-09-05                5693           15/9-F-4            NaN
# ...         ...                 ...                ...            ...
# 3322 2016-10-05                5693           15/9-F-4            NaN
# 3323 2016-10-06                5693           15/9-F-4            NaN
# 3324 2016-10-07                5693           15/9-F-4            NaN
# 3325 2016-11-01                5693           15/9-F-4            NaN
# 3326 2016-12-01                5693           15/9-F-4            NaN
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# ...

# %%
sns.heatmap(df_well6.isna())
# Out:
# <Axes: >

# %%
df_well6.plot(subplots=True,figsize=(16,8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df_well6["BORE_WI_VOL"].loc[0:500].plot(figsize=(16,4))
# Out:
# <Axes: >

# %%
df_well6.isna().sum()
# Out:
# DATEPRD                        0
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                152
# AVG_DOWNHOLE_PRESSURE       3327
# AVG_DOWNHOLE_TEMPERATURE    3327
# AVG_DP_TUBING               3327
# AVG_ANNULUS_PRESS           3327
# AVG_CHOKE_SIZE_P            3327
# AVG_CHOKE_UOM               3327
# AVG_WHP_P                   3327
# AVG_WHT_P                   3327
# DP_CHOKE_SIZE                154
# BORE_OIL_VOL                3327
# BORE_GAS_VOL                3327
# BORE_WAT_VOL                3327
# BORE_WI_VOL                  337
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
df_well6= df_well6.drop(["AVG_DOWNHOLE_PRESSURE","AVG_DOWNHOLE_TEMPERATURE","AVG_DP_TUBING","AVG_ANNULUS_PRESS","AVG_CHOKE_SIZE_P","AVG_CHOKE_UOM","AVG_WHP_P",
                        "AVG_WHT_P","BORE_OIL_VOL","BORE_GAS_VOL","BORE_WAT_VOL"],axis=1)
#df_well6["DP_CHOKE_SIZE"] = df_well6["DP_CHOKE_SIZE"].interpolate(method="linear")
#df_well6["ON_STREAM_HRS"] = df_well6["ON_STREAM_HRS"].interpolate(method="linear")
#df_well6["BORE_WI_VOL"] = df_well6["BORE_WI_VOL"].interpolate(method="linear")

# %%
df_well6["DP_CHOKE_SIZE"] = df_well6["DP_CHOKE_SIZE"].interpolate(method="linear")
df_well6["ON_STREAM_HRS"] = df_well6["ON_STREAM_HRS"].interpolate(method="linear")
df_well6["BORE_WI_VOL"] = df_well6["BORE_WI_VOL"].interpolate(method="linear")

# %%
sns.heatmap(df_well6.isna())
# Out:
# <Axes: >

# %%
df_well6[["DP_CHOKE_SIZE","BORE_WI_VOL"]].loc[1:500].plot(figsize=(16,6))
# Out:
# <Axes: >

# %%
df_well6.plot(subplots=True,figsize=(16,6))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df_well6.dropna().corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 df_well6.dropna().corr()
#
# File c:\Users\tutua\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\tutua\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df_well6.isna().sum()
# Out:
# DATEPRD                 0
# NPD_WELL_BORE_CODE      0
# NPD_WELL_BORE_NAME      0
# ON_STREAM_HRS         122
# DP_CHOKE_SIZE         122
# BORE_WI_VOL           235
# FLOW_KIND               0
# WELL_TYPE               0
# dtype: int64
