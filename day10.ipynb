# %% [markdown]
# ## Pandas :
#
# - extremely powerful version of excel in python, with more functionality
#
# #### Raw Data ----> Import to pandas -----> Analyze, Manipulate, Process, Do the data sciemce
#
#
# -- Series
#
# -- DataFrames
#
# -- Data manipulation
#
# -- Data I/O

# %% [markdown]
# # Series
# Array + LAbel = Series

# %%
import numpy as np
import pandas as pd

# %%
por = np.array([0.25,0.36,0.46,0.56])

# %%
por
# Out:
# array([0.25, 0.36, 0.46, 0.56])

# %%
por_series = pd.Series(data=por, index = ["a","b","c","d"])

# %%
por_series
# Out:
# a    0.25
# b    0.36
# c    0.46
# d    0.56
# dtype: float64

# %%
data_series = pd.Series(data=por, index = ["1200","1250","1300","1350"], name = "por vs depth")

# %%
data_series
# Out:
# 1200    0.25
# 1250    0.36
# 1300    0.46
# 1350    0.56
# Name: por vs depth, dtype: float64

# %%
##  Inbuilt poltting in pandas
data_series.plot()
# Out:
# <Axes: >

# %%
field = {"sandstone":210,"limestone":160,"dolomite":140}

# %%
field
# Out:
# {'sandstone': 210, 'limestone': 160, 'dolomite': 140}

# %%
field_series = pd.Series(data = field, name = " permeability")

# %%
field_series
# Out:
# sandstone    210
# limestone    160
# dolomite     140
# Name:  permeability, dtype: int64

# %%
field_series.plot()
# Out:
# <Axes: >

# %%
field_series.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Dataframe: bunch of series together having the same index
#
# df=table

# %%
common_depth_index = [1000,1500,2000]

poro_series_1= pd.Series(data = [0.35,0.21,0.17], index=common_depth_index)
poro_series_2= pd.Series(data =[0.32,0.20,0.16], index=common_depth_index)

# %%
poro_series_1
# Out:
# 1000    0.35
# 1500    0.21
# 2000    0.17
# dtype: float64

# %%
poro_series_2
# Out:
# 1000    0.32
# 1500    0.20
# 2000    0.16
# dtype: float64

# %%
pd.DataFrame([poro_series_1,poro_series_2]).T
# Out:
#          0     1
# 1000  0.35  0.32
# 1500  0.21  0.20
# 2000  0.17  0.16

# %%
## dataframe using dictionary

my_field_data = {"depth":[1000,1500,2000], "poro(%)":[35,30,25], "perm(md)":[500,450,150]}

# %%
my_field_data
# Out:
# {'depth': [1000, 1500, 2000],
#  'poro(%)': [35, 30, 25],
#  'perm(md)': [500, 450, 150]}

# %%
df_field = pd.DataFrame(my_field_data)

# %%
df_field
# Out:
#    depth  poro(%)  perm(md)
# 0   1000       35       500
# 1   1500       30       450
# 2   2000       25       150

# %%
df_field.plot()
# Out:
# <Axes: >

# %%
df_field.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
## Accesing colums and rows

# %%
df_field
# Out:
#    depth  poro(%)  perm(md)
# 0   1000       35       500
# 1   1500       30       450
# 2   2000       25       150

# %%
## Accesing colums

df_field["perm(md)"]
# Out:
# 0    500
# 1    450
# 2    150
# Name: perm(md), dtype: int64

# %%
type(df_field["perm(md)"])
# Out:
# pandas.core.series.Series

# %%
df_field[["perm(md)"]]
# Out:
#    perm(md)
# 0       500
# 1       450
# 2       150

# %%
df_field[["poro(%)","depth","perm(md)"]]
# Out:
#    poro(%)  depth  perm(md)
# 0       35   1000       500
# 1       30   1500       450
# 2       25   2000       150

# %%
df_field.index = df_field["depth"]

# %%
df_field
# Out:
#        depth  poro(%)  perm(md)
# depth
# 1000    1000       35       500
# 1500    1500       30       450
# 2000    2000       25       150

# %% [markdown]
# ## Access Rows
# 1. loc : index label
# 2. iloc: index number

# %%
df_field
# Out:
#        depth  poro(%)  perm(md)
# depth
# 1000    1000       35       500
# 1500    1500       30       450
# 2000    2000       25       150

# %%
df_field.loc[1500]
# Out:
# depth       1500
# poro(%)       30
# perm(md)     450
# Name: 1500, dtype: int64

# %%
df_field.iloc[1]
# Out:
# depth       1500
# poro(%)       30
# perm(md)     450
# Name: 1500, dtype: int64

# %%
depth = np.arange(1000,6000,500)

porosity = np.linspace(40,10,10)

perm = np.linspace(500,100,10)

reservoir_pressure = np.linspace(3000,4500,10)

# %%
len(perm)
# Out:
# 10

# %%
df = pd.DataFrame({"depth":depth,"porosity":porosity,"perm":perm,"Rpressure":reservoir_pressure})

# %%
df
# Out:
#    depth   porosity        perm    Rpressure
# 0   1000  40.000000  500.000000  3000.000000
# 1   1500  36.666667  455.555556  3166.666667
# 2   2000  33.333333  411.111111  3333.333333
# 3   2500  30.000000  366.666667  3500.000000
# 4   3000  26.666667  322.222222  3666.666667
# 5   3500  23.333333  277.777778  3833.333333
# 6   4000  20.000000  233.333333  4000.000000
# 7   4500  16.666667  188.888889  4166.666667
# 8   5000  13.333333  144.444444  4333.333333
# 9   5500  10.000000  100.000000  4500.000000

# %%
df.index = df["depth"]

# %%
df
# Out:
#        depth   porosity        perm    Rpressure
# depth
# 1000    1000  40.000000  500.000000  3000.000000
# 1500    1500  36.666667  455.555556  3166.666667
# 2000    2000  33.333333  411.111111  3333.333333
# 2500    2500  30.000000  366.666667  3500.000000
# 3000    3000  26.666667  322.222222  3666.666667
# 3500    3500  23.333333  277.777778  3833.333333
# 4000    4000  20.000000  233.333333  4000.000000
# 4500    4500  16.666667  188.888889  4166.666667
# 5000    5000  13.333333  144.444444  4333.333333
# 5500    5500  10.000000  100.000000  4500.000000

# %%
df.loc[4000]
# Out:
# depth        4000.000000
# porosity       20.000000
# perm          233.333333
# Rpressure    4000.000000
# Name: 4000, dtype: float64

# %%
df.iloc[6]
# Out:
# depth        4000.000000
# porosity       20.000000
# perm          233.333333
# Rpressure    4000.000000
# Name: 4000, dtype: float64

# %%
depth = np.arange(1000,3000,200)

perm = np.linspace(100,300,10)

poro = np.linspace(60,10,10)

res_pressure = np.linspace(1500,4500,10)

# %%
df = pd.DataFrame({"depth":depth,"permeability":perm,"porosity":poro,"Rpressure":res_pressure})

# %%
df
# Out:
#    depth  permeability   porosity    Rpressure
# 0   1000    100.000000  60.000000  1500.000000
# 1   1200    122.222222  54.444444  1833.333333
# 2   1400    144.444444  48.888889  2166.666667
# 3   1600    166.666667  43.333333  2500.000000
# 4   1800    188.888889  37.777778  2833.333333
# 5   2000    211.111111  32.222222  3166.666667
# 6   2200    233.333333  26.666667  3500.000000
# 7   2400    255.555556  21.111111  3833.333333
# 8   2600    277.777778  15.555556  4166.666667
# 9   2800    300.000000  10.000000  4500.000000

# %%
df.index = df["depth"]

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure
# depth
# 1000    1000    100.000000  60.000000  1500.000000
# 1200    1200    122.222222  54.444444  1833.333333
# 1400    1400    144.444444  48.888889  2166.666667
# 1600    1600    166.666667  43.333333  2500.000000
# 1800    1800    188.888889  37.777778  2833.333333
# 2000    2000    211.111111  32.222222  3166.666667
# 2200    2200    233.333333  26.666667  3500.000000
# 2400    2400    255.555556  21.111111  3833.333333
# 2600    2600    277.777778  15.555556  4166.666667
# 2800    2800    300.000000  10.000000  4500.000000

# %%
df.loc[2200]
# Out:
# depth           2200.000000
# permeability     233.333333
# porosity          26.666667
# Rpressure       3500.000000
# Name: 2200, dtype: float64

# %%
df.iloc[5]
# Out:
# depth           2000.000000
# permeability     211.111111
# porosity          32.222222
# Rpressure       3166.666667
# Name: 2000, dtype: float64

# %%
df.loc[1200:2400]
# Out:
#        depth  permeability   porosity    Rpressure
# depth
# 1200    1200    122.222222  54.444444  1833.333333
# 1400    1400    144.444444  48.888889  2166.666667
# 1600    1600    166.666667  43.333333  2500.000000
# 1800    1800    188.888889  37.777778  2833.333333
# 2000    2000    211.111111  32.222222  3166.666667
# 2200    2200    233.333333  26.666667  3500.000000
# 2400    2400    255.555556  21.111111  3833.333333

# %%
df.iloc[4:8]
# Out:
#        depth  permeability   porosity    Rpressure
# depth
# 1800    1800    188.888889  37.777778  2833.333333
# 2000    2000    211.111111  32.222222  3166.666667
# 2200    2200    233.333333  26.666667  3500.000000
# 2400    2400    255.555556  21.111111  3833.333333

# %%
df.iloc[4:8][["porosity","Rpressure"]]
# Out:
#         porosity    Rpressure
# depth
# 1800   37.777778  2833.333333
# 2000   32.222222  3166.666667
# 2200   26.666667  3500.000000
# 2400   21.111111  3833.333333

# %%
df[["porosity","Rpressure"]].iloc[4:8]
# Out:
#         porosity    Rpressure
# depth
# 1800   37.777778  2833.333333
# 2000   32.222222  3166.666667
# 2200   26.666667  3500.000000
# 2400   21.111111  3833.333333

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure
# depth
# 1000    1000    100.000000  60.000000  1500.000000
# 1200    1200    122.222222  54.444444  1833.333333
# 1400    1400    144.444444  48.888889  2166.666667
# 1600    1600    166.666667  43.333333  2500.000000
# 1800    1800    188.888889  37.777778  2833.333333
# 2000    2000    211.111111  32.222222  3166.666667
# 2200    2200    233.333333  26.666667  3500.000000
# 2400    2400    255.555556  21.111111  3833.333333
# 2600    2600    277.777778  15.555556  4166.666667
# 2800    2800    300.000000  10.000000  4500.000000

# %%
df["wob"] = np.linspace(50,5,10)

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0
# 2000    2000    211.111111  32.222222  3166.666667  25.0
# 2200    2200    233.333333  26.666667  3500.000000  20.0
# 2400    2400    255.555556  21.111111  3833.333333  15.0
# 2600    2600    277.777778  15.555556  4166.666667  10.0
# 2800    2800    300.000000  10.000000  4500.000000   5.0

# %%
df["num"] = np.linspace(0,9,10)

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0

# %%
df.iloc[2:3][["wob","porosity"]]
# Out:
#         wob   porosity
# depth
# 1400   40.0  48.888889

# %%
df[["wob","porosity"]]
# Out:
#         wob   porosity
# depth
# 1000   50.0  60.000000
# 1200   45.0  54.444444
# 1400   40.0  48.888889
# 1600   35.0  43.333333
# 1800   30.0  37.777778
# 2000   25.0  32.222222
# 2200   20.0  26.666667
# 2400   15.0  21.111111
# 2600   10.0  15.555556
# 2800    5.0  10.000000

# %%
#dropping data

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0

# %%
ff = df.drop("depth",axis =1)

# %%
ff
# Out:
#        permeability   porosity    Rpressure   wob  num
# depth
# 1000     100.000000  60.000000  1500.000000  50.0  0.0
# 1200     122.222222  54.444444  1833.333333  45.0  1.0
# 1400     144.444444  48.888889  2166.666667  40.0  2.0
# 1600     166.666667  43.333333  2500.000000  35.0  3.0
# 1800     188.888889  37.777778  2833.333333  30.0  4.0
# 2000     211.111111  32.222222  3166.666667  25.0  5.0
# 2200     233.333333  26.666667  3500.000000  20.0  6.0
# 2400     255.555556  21.111111  3833.333333  15.0  7.0
# 2600     277.777778  15.555556  4166.666667  10.0  8.0
# 2800     300.000000  10.000000  4500.000000   5.0  9.0

# %%
ff["depth"]= np.linspace(1000,3000,10)

# %%
ff
# Out:
#        permeability   porosity    Rpressure   wob  num        depth
# depth
# 1000     100.000000  60.000000  1500.000000  50.0  0.0  1000.000000
# 1200     122.222222  54.444444  1833.333333  45.0  1.0  1222.222222
# 1400     144.444444  48.888889  2166.666667  40.0  2.0  1444.444444
# 1600     166.666667  43.333333  2500.000000  35.0  3.0  1666.666667
# 1800     188.888889  37.777778  2833.333333  30.0  4.0  1888.888889
# 2000     211.111111  32.222222  3166.666667  25.0  5.0  2111.111111
# 2200     233.333333  26.666667  3500.000000  20.0  6.0  2333.333333
# 2400     255.555556  21.111111  3833.333333  15.0  7.0  2555.555556
# 2600     277.777778  15.555556  4166.666667  10.0  8.0  2777.777778
# 2800     300.000000  10.000000  4500.000000   5.0  9.0  3000.000000

# %%
ff = ff.drop("depth",axis =1)

# %%
ff
# Out:
#        permeability   porosity    Rpressure   wob  num
# depth
# 1000     100.000000  60.000000  1500.000000  50.0  0.0
# 1200     122.222222  54.444444  1833.333333  45.0  1.0
# 1400     144.444444  48.888889  2166.666667  40.0  2.0
# 1600     166.666667  43.333333  2500.000000  35.0  3.0
# 1800     188.888889  37.777778  2833.333333  30.0  4.0
# 2000     211.111111  32.222222  3166.666667  25.0  5.0
# 2200     233.333333  26.666667  3500.000000  20.0  6.0
# 2400     255.555556  21.111111  3833.333333  15.0  7.0
# 2600     277.777778  15.555556  4166.666667  10.0  8.0
# 2800     300.000000  10.000000  4500.000000   5.0  9.0

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1000 to 2800
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   permeability  10 non-null     float64
#  1   porosity      10 non-null     float64
#  2   Rpressure     10 non-null     float64
#  3   wob           10 non-null     float64
#  4   num           10 non-null     float64
# dtypes: float64(5)
# memory usage: 676.0 bytes

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1000 to 2800
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   depth         10 non-null     int32
#  1   permeability  10 non-null     float64
#  2   porosity      10 non-null     float64
#  3   Rpressure     10 non-null     float64
#  4   wob           10 non-null     float64
#  5   num           10 non-null     float64
# dtypes: float64(5), int32(1)
# memory usage: 716.0 bytes

# %%
df.head()
# Out:
#        depth  permeability   porosity    Rpressure   wob  num
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0

# %%
df.describe()
# Out:
#              depth  permeability  porosity    Rpressure        wob       num
# count    10.000000     10.000000  10.00000    10.000000  10.000000  10.00000
# mean   1900.000000    200.000000  35.00000  3000.000000  27.500000   4.50000
# std     605.530071     67.281119  16.82028  1009.216785  15.138252   3.02765
# min    1000.000000    100.000000  10.00000  1500.000000   5.000000   0.00000
# 25%    1450.000000    150.000000  22.50000  2250.000000  16.250000   2.25000
# 50%    1900.000000    200.000000  35.00000  3000.000000  27.500000   4.50000
# 75%    2350.000000    250.000000  47.50000  3750.000000  38.750000   6.75000
# max    2800.000000    300.000000  60.00000  4500.000000  50.000000   9.00000

# %%
ff.describe()
# Out:
#        permeability  porosity    Rpressure        wob       num
# count     10.000000  10.00000    10.000000  10.000000  10.00000
# mean     200.000000  35.00000  3000.000000  27.500000   4.50000
# std       67.281119  16.82028  1009.216785  15.138252   3.02765
# min      100.000000  10.00000  1500.000000   5.000000   0.00000
# 25%      150.000000  22.50000  2250.000000  16.250000   2.25000
# 50%      200.000000  35.00000  3000.000000  27.500000   4.50000
# 75%      250.000000  47.50000  3750.000000  38.750000   6.75000
# max      300.000000  60.00000  4500.000000  50.000000   9.00000

# %% [markdown]
# ## Conditional Selection:

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0

# %%
df["lithology"] = np.random.choice(["sandstone","limestone","shale"],size = (10,))

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
# lithology is shale
df["lithology"]
# Out:
# depth
# 1000        shale
# 1200    sandstone
# 1400    sandstone
# 1600        shale
# 1800    limestone
# 2000    sandstone
# 2200    limestone
# 2400    limestone
# 2600    sandstone
# 2800        shale
# Name: lithology, dtype: object

# %%
df["lithology"] == "shale"
# Out:
# depth
# 1000     True
# 1200    False
# 1400    False
# 1600     True
# 1800    False
# 2000    False
# 2200    False
# 2400    False
# 2600    False
# 2800     True
# Name: lithology, dtype: bool

# %%
df[df["lithology"] == "shale"]
# Out:
#        depth  permeability   porosity  Rpressure   wob  num lithology
# depth
# 1000    1000    100.000000  60.000000     1500.0  50.0  0.0     shale
# 1600    1600    166.666667  43.333333     2500.0  35.0  3.0     shale
# 2800    2800    300.000000  10.000000     4500.0   5.0  9.0     shale

# %%
df["lithology"] == "limstone"
# Out:
# depth
# 1000    False
# 1200    False
# 1400    False
# 1600    False
# 1800    False
# 2000    False
# 2200    False
# 2400    False
# 2600    False
# 2800    False
# Name: lithology, dtype: bool

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df = df.drop("litology",axis =1)

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df[df["lithology"] == "shale"]
# Out:
#        depth  permeability   porosity  Rpressure   wob  num lithology
# depth
# 1000    1000    100.000000  60.000000     1500.0  50.0  0.0     shale
# 1600    1600    166.666667  43.333333     2500.0  35.0  3.0     shale
# 2800    2800    300.000000  10.000000     4500.0   5.0  9.0     shale

# %%
df[df["lithology"] == "limestone"]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone

# %%
df[df["lithology"] == "sandstone"]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone

# %%
### data where my porosity is greater than 15

a =5
b= 6
a<b
# Out:
# True

# %%
df[df['porosity']>35]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone

# %%
(df["lithology"] == "limestone") & (df["porosity"] > 25)
# Out:
# depth
# 1000    False
# 1200    False
# 1400    False
# 1600    False
# 1800     True
# 2000    False
# 2200     True
# 2400    False
# 2600    False
# 2800    False
# dtype: bool

# %%
df[(df["lithology"] == "limestone") & (df["porosity"] > 25)]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone

# %%
df[(df["lithology"] != "limestone") & (df["porosity"] > 25)]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df[(df["permeability"] > 150) & (df["Rpressure"] > 4000)]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df[(df["permeability"] < 150) & (df["Rpressure"] > 400)]
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df.to_csv("field_properties.csv")

# %%
df
# Out:
#        depth  permeability   porosity    Rpressure   wob  num  lithology
# depth
# 1000    1000    100.000000  60.000000  1500.000000  50.0  0.0      shale
# 1200    1200    122.222222  54.444444  1833.333333  45.0  1.0  sandstone
# 1400    1400    144.444444  48.888889  2166.666667  40.0  2.0  sandstone
# 1600    1600    166.666667  43.333333  2500.000000  35.0  3.0      shale
# 1800    1800    188.888889  37.777778  2833.333333  30.0  4.0  limestone
# 2000    2000    211.111111  32.222222  3166.666667  25.0  5.0  sandstone
# 2200    2200    233.333333  26.666667  3500.000000  20.0  6.0  limestone
# 2400    2400    255.555556  21.111111  3833.333333  15.0  7.0  limestone
# 2600    2600    277.777778  15.555556  4166.666667  10.0  8.0  sandstone
# 2800    2800    300.000000  10.000000  4500.000000   5.0  9.0      shale

# %%
df_read = pd.read_csv("field_properties.csv")

# %%
df_read
# Out:
#    depth  depth.1  permeability  porosity  Rpressure   wob  num  lithology
# 0   1000     1000        100.00     60.00    1500.00  50.0    0      shale
# 1   1200     1200        122.22     54.44    1833.33  45.0    1  sandstone
# 2   1400     1400        144.44     48.89    2166.67  40.0    2  sandstone
# 3   1600     1600        166.67     43.33    2500.00  35.0    3      shale
# 4   1800     1800        188.89     37.78    2833.33  30.0    4  limestone
# 5   2000     2000        211.11     32.22    3166.67  25.0    5  sandstone
# 6   2200     2200        233.33     26.67    3500.00  20.0    6  limestone
# 7   2400     2400        255.56     21.11    3833.33  15.0    7  limestone
# 8   2600     2600        277.78     15.56    4166.67  10.0    8  sandstone
# 9   2800     2800        400.00     10.00    4500.00   5.0    9      shale

# %%
df_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   depth         10 non-null     int64
#  1   depth.1       10 non-null     int64
#  2   permeability  10 non-null     float64
#  3   porosity      10 non-null     float64
#  4   Rpressure     10 non-null     float64
#  5   wob           10 non-null     float64
#  6   num           10 non-null     int64
#  7   lithology     10 non-null     object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 772.0+ bytes

# %%
bh_0121 = pd.read_excel("bh_0121.xlsx")

# %%
bh_0121
# Out:
#     DEPTH      ROP    WOB  BIT_RPM       TORQUE    MTI     MTO   MWI   MWO  \
# 0     916   6.0000  26.54   100.20  2518.655996  32.00  110.15  9.50  9.50
# 1     917   4.9343  26.00   101.94  2455.440315  32.00  110.37  9.50  9.50
# 2     918   5.8001  24.00   100.17  2457.377374  32.00  110.50  9.50  9.50
# 3     919   4.4858  25.00   101.71  2456.806972  32.00  110.65  9.51  9.51
# 4     920   4.8982  26.70   100.80  2456.261937  32.00  110.83  9.51  9.50
# ..    ...      ...    ...      ...          ...    ...     ...   ...   ...
# 80    996  81.0701   5.14    78.97     0.000000  92.31  115.09  8.81  8.80
# 81    997  60.1724   8.84    79.15     0.000000  93.96  115.09  8.81  8.80
# 82    998  54.8696   8.59    78.91     0.000000  96.43  115.08  8.81  8.81
# 83    999  35.7988   8.44    79.18     0.000000  92.80  115.03  8.81  8.81
# 84   1000  64.4652   6.74    78.66     0.000000  94.31  115.05  8.81  8.81
#
#      ECD  FLOWIN  FLOWOUT      SPP  Pump1  Pump2
# ...

# %%
bh_0121.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEPTH    85 non-null     int64
#  1   ROP      85 non-null     float64
#  2   WOB      85 non-null     float64
#  3   BIT_RPM  85 non-null     float64
#  4   TORQUE   85 non-null     float64
#  5   MTI      85 non-null     float64
#  6   MTO      85 non-null     float64
#  7   MWI      85 non-null     float64
#  8   MWO      85 non-null     float64
#  9   ECD      85 non-null     float64
#  10  FLOWIN   85 non-null     float64
#  11  FLOWOUT  85 non-null     float64
#  12  SPP      85 non-null     float64
#  13  Pump1    85 non-null     float64
#  14  Pump2    85 non-null     float64
# dtypes: float64(14), int64(1)
# memory usage: 10.1 KB

# %%
bh_0121.describe()
# Out:
#              DEPTH         ROP        WOB     BIT_RPM       TORQUE        MTI  \
# count    85.000000   85.000000  85.000000   85.000000    85.000000  85.000000
# mean    958.000000   79.703128  23.308471   97.722706  1617.301893  60.486235
# std      24.681302   58.037468  15.257018   10.644005  1010.078786  31.131145
# min     916.000000    4.485800   4.140000   78.430000     0.000000  32.000000
# 25%     937.000000   34.367500   8.180000  100.030000  1195.679056  32.000000
# 50%     958.000000   70.674100  26.000000  100.770000  2450.150977  32.000000
# 75%     979.000000  113.054600  39.480000  101.940000  2458.528215  93.990000
# max    1000.000000  233.432700  39.860000  109.330000  2518.655996  98.260000
#
#               MTO        MWI        MWO        ECD      FLOWIN    FLOWOUT  \
# count   85.000000  85.000000  85.000000  85.000000   85.000000  85.000000
# mean   113.031176   9.361176   9.363882   9.423412  676.892706  29.803882
# ...

# %%
ROP_WOB = bh_0121.iloc[4:25][["DEPTH","ROP","WOB"]]

# %%
ROP_WOB
# Out:
#     DEPTH       ROP    WOB
# 4     920    4.8982  26.70
# 5     921    9.0927  26.32
# 6     922    8.5714  26.30
# 7     923    8.5845  28.83
# 8     924   10.1942  39.49
# 9     925   14.1497  39.48
# 10    926    7.0316  39.50
# 11    927   14.3802  39.51
# 12    928   28.5288  39.52
# 13    929   20.8563  39.43
# 14    930   68.0851  39.38
# 15    931   70.6741  39.31
# 16    932   87.5720  39.29
# 17    933   80.7573  39.78
# 18    934  106.4679  39.56
# 19    935  158.8982  39.50
# 20    936   82.6408  39.56
# 21    937  106.7140  39.39
# 22    938   74.5387  39.45
# 23    939   91.1392  39.59
# 24    940   34.3062  39.58

# %%
ROP_WOB.plot()
# Out:
# <Axes: >

# %%
ROP_WOB.describe()
# Out:
#             DEPTH         ROP        WOB
# count   21.000000   21.000000  21.000000
# mean   930.000000   51.813386  37.117619
# std      6.204837   44.355179   5.033220
# min    920.000000    4.898200  26.300000
# 25%    925.000000   10.194200  39.310000
# 50%    930.000000   34.306200  39.480000
# 75%    935.000000   82.640800  39.520000
# max    940.000000  158.898200  39.780000

# %%
bh_0121
# Out:
#     DEPTH      ROP    WOB  BIT_RPM       TORQUE    MTI     MTO   MWI   MWO  \
# 0     916   6.0000  26.54   100.20  2518.655996  32.00  110.15  9.50  9.50
# 1     917   4.9343  26.00   101.94  2455.440315  32.00  110.37  9.50  9.50
# 2     918   5.8001  24.00   100.17  2457.377374  32.00  110.50  9.50  9.50
# 3     919   4.4858  25.00   101.71  2456.806972  32.00  110.65  9.51  9.51
# 4     920   4.8982  26.70   100.80  2456.261937  32.00  110.83  9.51  9.50
# ..    ...      ...    ...      ...          ...    ...     ...   ...   ...
# 80    996  81.0701   5.14    78.97     0.000000  92.31  115.09  8.81  8.80
# 81    997  60.1724   8.84    79.15     0.000000  93.96  115.09  8.81  8.80
# 82    998  54.8696   8.59    78.91     0.000000  96.43  115.08  8.81  8.81
# 83    999  35.7988   8.44    79.18     0.000000  92.80  115.03  8.81  8.81
# 84   1000  64.4652   6.74    78.66     0.000000  94.31  115.05  8.81  8.81
#
#      ECD  FLOWIN  FLOWOUT      SPP  Pump1  Pump2
# ...

# %%
bh_0121.plot()
# Out:
# <Axes: >

# %%
ROP_WOB = bh_0121.iloc[4:25][["DEPTH","TORQUE","FLOWIN","SPP","ROP","WOB"]]

# %%
ROP_WOB
# Out:
#     DEPTH       TORQUE  FLOWIN     SPP       ROP    WOB
# 4     920  2456.261937  735.78  938.31    4.8982  26.70
# 5     921  2457.713104  735.83  939.56    9.0927  26.32
# 6     922  2457.274959  735.95  952.99    8.5714  26.30
# 7     923  2460.319316  735.81  944.04    8.5845  28.83
# 8     924  2458.499864  735.94  954.33   10.1942  39.49
# 9     925  2459.507054  735.71  938.28   14.1497  39.48
# 10    926  2457.694248  735.91  898.94    7.0316  39.50
# 11    927  2450.150977  735.61  896.49   14.3802  39.51
# 12    928  2464.618692  735.81  843.14   28.5288  39.52
# 13    929  2455.101329  735.72  875.07   20.8563  39.43
# 14    930  2451.504476  735.82  897.92   68.0851  39.38
# 15    931  2448.757596  735.97  863.60   70.6741  39.31
# 16    932  2449.892431  735.58  894.38   87.5720  39.29
# 17    933  2460.006104  736.11  881.44   80.7573  39.78
# 18    934  2456.732637  736.10  876.50  106.4679  39.56
# 19    935  2462.464731  735.67  899.71  158.8982  39.50
# ...

# %%
ROP_WOB.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)
